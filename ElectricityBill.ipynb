# %%
units = float(input("Enter electricity units consumed: "))
bill = 0

if units > 0:
    if units <= 100:
        bill = units * 2
    elif units <= 200:
        bill = (100 * 2) + ((units - 100) * 3)
    elif units <= 500:
        bill = (100 * 2) + (100 * 3) + ((units - 200) * 5)
    else:
        bill = (100 * 2) + (100 * 3) + (300 * 5) + ((units - 500) * 8)

    bill += 50  # Fixed charge
    print(f"Total electricity bill for {units} units is ₹{bill}")
else:
    print("Invalid input. Units must be greater than 0.")
# Out:
# Total electricity bill for 3333.0 units is ₹24714.0
